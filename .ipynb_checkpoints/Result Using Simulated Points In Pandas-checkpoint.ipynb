# %% [markdown]
# # Trilateration Using Least Squares
#
# ## Test Data Generation
# Script is to provide some test data for the trilateration algorithm.
#
# The first section generates a random grid of shots, assigns some FBP value with some error.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

#create sample points
dataX = pd.DataFrame(np.random.randint(2000000,2002000,size=(2000,1)), columns=list('X'))
dataY = pd.DataFrame(np.random.randint(3000000,3002000,size=(2000,1)), columns=list('Y'))
dataZ = pd.DataFrame(np.random.uniform(-7,-5,size=(2000,1)), columns=list('Z'))
error = pd.DataFrame(np.random.uniform(-10,10,size=(2000,1)), columns=list('E'))
data = pd.concat([dataX, dataY, dataZ, error], axis=1, sort=False)

#intial and target values
Xi=2001041.0
Yi=3000967.0
Zi=-30.0
Si=1535.0 


#distances to intial point with error
data['fbp'] = ((((data['X']-Xi+(data['E']))**2 + (data['Y']-Yi+(data['E']))**2 + (data['Z']-Zi+(data['E']))**2)**0.5))/(Si + data['E'])

data.head()
# Out:
#          X        Y         Z         E       fbp
# 0  2001012  3001886 -5.116293 -3.186678  0.598399
# 1  2000841  3001506 -5.235537  7.469831  0.376208
# 2  2000502  3001921 -5.937906 -5.358528  0.715129
# 3  2000814  3001748 -5.808180  2.665315  0.530405
# 4  2000249  3001154 -5.363000  7.343907  0.524525

# %% [markdown]
# ## Finding The Calculated Position
# The next section calculates the final actual point where the FBP falls by scaling.

# %%
#calculate the observed distance
data['observed_dist']=(data['fbp']*Si)

#calculated ranges
data['calc_ranges']=((data['X']-Xi)**2 + (data['Y']-Yi)**2 + (data['Z']-Zi)**2)**0.5

#scaling
data['scale']=data['observed_dist']/data['calc_ranges']

#diffs
data['diff_X']= data['X']-Xi
data['diff_Y']= data['Y']-Yi
data['diff_Z']= data['Z']-Zi

#scaling
data['diff_X_scaled']= (data['X']-Xi)*data['scale']
data['diff_Y_scaled']= (data['Y']-Yi)*data['scale']
data['diff_Z_scaled']= (data['Z']-Zi)*data['scale']

#Final
data['final_X']= -data['diff_X_scaled']+data['X']
data['final_Y']= -data['diff_Y_scaled']+data['Y']
data['final_Z']= -data['diff_Z_scaled']+data['Z']

#Final_Diff
data['final_diff']=((data['final_X']-Xi)**2 + (data['final_Y']-Yi)**2 + (data['final_Z']-Zi)**2)**0.5


data.head()
# Out:
#          X        Y         Z         E       fbp  observed_dist  calc_ranges  \
# 0  2001012  3001886 -5.116293 -3.186678  0.598399     918.542483   919.794107
# 1  2000841  3001506 -5.235537  7.469831  0.376208     577.479537   575.442681
# 2  2000502  3001921 -5.937906 -5.358528  0.715129    1097.722650  1095.999993
# 3  2000814  3001748 -5.808180  2.665315  0.530405     814.171176   813.680063
# 4  2000249  3001154 -5.363000  7.343907  0.524525     805.145785   814.149852
#
#       scale  diff_X  diff_Y     diff_Z  diff_X_scaled  diff_Y_scaled  \
# 0  0.998639   -29.0   919.0  24.883707     -28.960538     917.749457
# 1  1.003540  -200.0   539.0  24.764463    -200.707927     540.907862
# 2  1.001572  -539.0   954.0  24.062094    -539.847183     955.499466
# 3  1.000604  -227.0   781.0  24.191820    -227.137011     781.471389
# 4  0.988941  -792.0   187.0  24.637000    -783.240898     184.931879
#
#    diff_Z_scaled       final_X       final_Y    final_Z  final_diff
# 0      24.849847  2.001041e+06  3.000968e+06 -29.966139    1.251623
# 1      24.852121  2.001042e+06  3.000965e+06 -30.087657    2.036856
# 2      24.099914  2.001042e+06  3.000966e+06 -30.037820    1.722657
# 3      24.206421  2.001041e+06  3.000967e+06 -30.014601    0.491113
# 4      24.364528  2.001032e+06  3.000969e+06 -29.727528    9.004068

# %% [markdown]
# ## Unfiltered Data
# As can be seen the final offset from the observed FBP to the calulated point is normally distributed. This provides some opportunities for filtering and optimising the least squares attempt.
#
# There are also some possibilities of filtering on distance from the point based on the calculated ranges. Closer ranges should be given a higher weighting.

# %%
data['final_diff'].hist()

# %%
data['calc_ranges'].hist()

# %%
data.plot.scatter('X', 'Y')

# %%
ax = plt.axes(projection='3d')
xdata = (data.X.tolist())
ydata = (data.Y.tolist())
zdata = (data.Z.tolist())

ax.scatter3D(xdata, ydata, zdata);

# %%
data.plot.scatter('final_X', 'final_Y')

# %%
ax = plt.axes(projection='3d')
xdata = (data.final_X.tolist())
ydata = (data.final_Y.tolist())
zdata = (data.final_Z.tolist())

ax.scatter3D(xdata, ydata, zdata);

# %%
x0data = (data.X.tolist())
y0data = (data.Y.tolist())

x1data = (data.final_X.tolist())
y1data = (data.final_Y.tolist())

for x0,y0,x1,y1 in zip(x0data,y0data,x1data,y1data):
    plt.plot([x0,x1],[y0,y1])

# %%
ax = plt.axes(projection='3d')
x0data = (data.X.tolist())
y0data = (data.Y.tolist())
z0data = (data.Z.tolist())
x1data = (data.final_X.tolist())
y1data = (data.final_Y.tolist())
z1data = (data.final_Z.tolist())

for x0,y0,z0,x1,y1,z1 in zip(x0data,y0data,z0data,x1data,y1data,z1data):
    ax.plot([x0,x1],[y0,y1],[z0,z1])

# %% [markdown]
# ## Filtered Data
# Showing the effects of filtering on the data by selecting the 500 closest inputs to the intial point.

# %%
filter = data.sort_values(by=['calc_ranges'])
filter = filter.head(22)
filter = filter.astype('float64', copy=False)

# %%
filter['final_diff'].hist()

# %%
filter['calc_ranges'].hist()

# %%
filter.plot.scatter('X', 'Y')

# %%
ax = plt.axes(projection='3d')
xdata = (filter.X.tolist())
ydata = (filter.Y.tolist())
zdata = (filter.Z.tolist())

ax.scatter3D(xdata, ydata, zdata);

# %%
filter.plot.scatter('final_X', 'final_Y')

# %%
ax = plt.axes(projection='3d')
xdata = (filter.final_X.tolist())
ydata = (filter.final_Y.tolist())
zdata = (filter.final_Z.tolist())
ax.scatter3D(xdata, ydata, zdata);

# %%
x0data = (filter.X.tolist())
y0data = (filter.Y.tolist())

x1data = (filter.final_X.tolist())
y1data = (filter.final_Y.tolist())

for x0,y0,x1,y1 in zip(x0data,y0data,x1data,y1data):
    plt.plot([x0,x1],[y0,y1])

# %%
ax = plt.axes(projection='3d')
x0data = (filter.X.tolist())
y0data = (filter.Y.tolist())
z0data = (filter.Z.tolist())
x1data = (filter.final_X.tolist())
y1data = (filter.final_Y.tolist())
z1data = (filter.final_Z.tolist())

for x0,y0,z0,x1,y1,z1 in zip(x0data,y0data,z0data,x1data,y1data,z1data):
    ax.plot([x0,x1],[y0,y1],[z0,z1])

# %% [markdown]
# ## Creating Least Squares Equations
# This is currently not needed but included here for reference.

# %%
#x_list=filter['X'].tolist()
#y_list=filter['Y'].tolist()
#z_list=filter['Z'].tolist()
#r_list=filter['observed_dist'].tolist()

#text_file = open("pos_dict.py","w")

#print("x1_list=",x_list, file=text_file)
#print("y1_list=",y_list, file=text_file)
#print("z1_list=",z_list, file=text_file)
#print("r1_list=",r_list, file=text_file)

#text_file.close()






#text_file = open("equations.py", "w")

#print("from pos_dict import *", file=text_file)
#print("def equations( guess, x_list=x_list, y_list=y_list,z_list=z_list, r_list=r_list ):", file=text_file)
#print("\tx, y, z, r = guess", file=text_file)
#print("\treturn (", file=text_file)

#i=0

#while i < len(filter.index):
#    print("\t\t(x - x_list",i,")**2 + (y - y_list",i,")**2 + (z - z_list",i,")**2 - (r_list",i," - r )**2,", sep="", file=text_file)
  
#    i=i+1
#print("\t)",file=text_file)    
    
#text_file.close()

# %% [markdown]
# ## Create Variables
# Create variables required for the equations.

# %%
i=0
while i < len(filter.index):
    globals()['x_%s' % i] = filter.iloc[i]['X']
    globals()['y_%s' % i] = filter.iloc[i]['Y']
    globals()['z_%s' % i] = filter.iloc[i]['Z']
    globals()['r_%s' % i] = filter.iloc[i]['observed_dist']
    i = i+1

# %% [markdown]
# ## Hard coded equations
# Since it is not possible (YET!) to get the equations imported from equations.py the below are hard coded.

# %%
def equations( guess ):
	x, y, z, r = guess
	return (
		(x - x_0)**2 + (y - y_0)**2 + (z - z_0)**2 - (r_0 - r )**2,
		(x - x_1)**2 + (y - y_1)**2 + (z - z_1)**2 - (r_1 - r )**2,
		(x - x_2)**2 + (y - y_2)**2 + (z - z_2)**2 - (r_2 - r )**2,
		(x - x_3)**2 + (y - y_3)**2 + (z - z_3)**2 - (r_3 - r )**2,
		(x - x_4)**2 + (y - y_4)**2 + (z - z_4)**2 - (r_4 - r )**2,
		(x - x_5)**2 + (y - y_5)**2 + (z - z_5)**2 - (r_5 - r )**2,
		(x - x_6)**2 + (y - y_6)**2 + (z - z_6)**2 - (r_6 - r )**2,
		(x - x_7)**2 + (y - y_7)**2 + (z - z_7)**2 - (r_7 - r )**2,
		(x - x_8)**2 + (y - y_8)**2 + (z - z_8)**2 - (r_8 - r )**2,
		(x - x_9)**2 + (y - y_9)**2 + (z - z_9)**2 - (r_9 - r )**2,
		(x - x_10)**2 + (y - y_10)**2 + (z - z_10)**2 - (r_10 - r )**2,
		(x - x_11)**2 + (y - y_11)**2 + (z - z_11)**2 - (r_11 - r )**2,
		(x - x_12)**2 + (y - y_12)**2 + (z - z_12)**2 - (r_12 - r )**2,
		(x - x_13)**2 + (y - y_13)**2 + (z - z_13)**2 - (r_13 - r )**2,
		(x - x_14)**2 + (y - y_14)**2 + (z - z_14)**2 - (r_14 - r )**2,
		(x - x_15)**2 + (y - y_15)**2 + (z - z_15)**2 - (r_15 - r )**2,
		(x - x_16)**2 + (y - y_16)**2 + (z - z_16)**2 - (r_16 - r )**2,
		(x - x_17)**2 + (y - y_17)**2 + (z - z_17)**2 - (r_17 - r )**2,
		(x - x_18)**2 + (y - y_18)**2 + (z - z_18)**2 - (r_18 - r )**2,
		(x - x_19)**2 + (y - y_19)**2 + (z - z_19)**2 - (r_19 - r )**2,
		(x - x_20)**2 + (y - y_20)**2 + (z - z_20)**2 - (r_20 - r )**2,
		(x - x_21)**2 + (y - y_21)**2 + (z - z_21)**2 - (r_21 - r )**2,
	)

# %% [markdown]
# ## Run The Least Squares

# %%
import scipy
from scipy.optimize import least_squares

# Make SciPy solve the system using an initial guess.
# The initial guess affects which of the "candidates" SciPy finds.
initial_guess = (Xi, Yi, Zi, 0)

#equations( initial_guess )
results = least_squares(equations, initial_guess)

results
# Out:
#  active_mask: array([0., 0., 0., 0.])
#         cost: 2430425.4040205684
#          fun: array([-315.28155084,  -81.09854882,  -49.60758175, -539.18005026,
#        -287.00013829,  490.70749933,  128.40968548,  460.02390597,
#          75.30234529,  740.59878069,  249.89591706,   55.00515875,
#        -843.78298056,  266.81093952,   80.95858312,   95.57737264,
#        -800.14606054, -617.90885646, -454.04514637,  -60.08186548,
#         396.13519805, 1050.33743048])
#         grad: array([-0.00481975, -0.06450205, -0.05958565, -0.0004184 ])
#          jac: array([[  62.80956797,   31.89096046,   -1.63085097,   78.86231701],
#        [  62.80956797,  -96.10903954,   -5.28660627,  116.35798977],
#        [-101.19043203,  -48.10903954,   -4.68260505,  113.06935458],
#        [  -1.19043203,  113.89096046,   -2.15821544,  122.97899568],
#        [-105.19043203,   51.89096046,   -3.46671535,  122.14478329],
#        [ -49.19043203, -112.10903954,   -3.54721891,  114.24031326],
#        [-115.19043203,  -64.10903954,   -2.35552282,  129.93588353],
#        [  28.80956797, -140.10903954,   -5.43188221,  136.60445949],
#        [ 140.80956797,  -80.10903954,   -2.18637632,  161.08120621],
#        [ 120.80956797,  111.89096046,   -2.06062153,  155.36796004],
#        [ -15.19043203,  161.89096046,   -3.97297689,  159.50572139],
#        [-159.19043203,   57.89096046,   -3.04464491,  168.77957079],
#        [  52.80956797, -168.10903954,   -1.8985901 ,  185.58058288],
#        [ 152.80956797,   85.89096046,   -2.88221164,  172.19845393],
#        [ 176.80956797,  -24.10903954,   -3.60674363,  177.54911795],
#        [  94.80956797,  149.89096046,   -3.99899458,  176.26911118],
#        [ -19.19043203,  175.89096046,   -3.07375132,  185.74546724],
#        [-127.19043203,  123.89096046,   -2.20572018,  184.38930439],
#        [ 126.80956797, -148.10903954,   -5.1934839 ,  199.66427183],
#        [-191.19043203,    3.89096046,   -4.0608713 ,  191.92922786],
#        [ 168.80956797,  105.89096046,   -2.12167879,  195.21792591],
#        [-197.19043203,   13.89096046,   -1.60299542,  186.78537648]])
#      message: '`xtol` termination condition is satisfied.'
#         nfev: 7
#         njev: 6
#   optimality: 0.06450204876273347
#       status: 3
#      success: True
#            x: array([ 2.00104239e+06,  3.00096592e+06, -7.74619450e+00,  1.94190906e+00])

# %%
#covar = (J^T J)^{-1}
import numpy as np
J = results.jac
JT = results.jac.transpose()

# %%
cov_matrix = pd.DataFrame((JT.dot(J))**-1)
cov_matrix
# Out:
#           0         1         2         3
# 0  0.000003 -0.000068 -0.002183  0.000040
# 1 -0.000068  0.000004 -0.017317  0.000016
# 2 -0.002183 -0.017317  0.003896 -0.000091
# 3  0.000040  0.000016 -0.000091  0.000002

# %%
cov_mat_xy = cov_matrix.drop([2,3], 1)
cov_mat_xy = cov_mat_xy.drop([2,3], 0)
cov_mat_xy

#http://www.visiondummy.com/2014/04/draw-error-ellipse-representing-covariance-matrix/
# Out:
#           0         1
# 0  0.000003 -0.000068
# 1 -0.000068  0.000004

# %%
from numpy import linalg as LA

LA.eig(cov_mat_xy)
# Out:
# (array([-6.46011347e-05,  7.18191647e-05]), array([[-0.7090179 ,  0.70519048],
#         [-0.70519048, -0.7090179 ]]))

# %%
print(results.x[0]-Xi,"metres diff in x")
print(results.x[1]-Yi,"metres diff in y")
print(results.x[2]-Zi,"metres diff in z")
# Out:
# 1.389875058317557 metres diff in x
# -1.0768787069246173 metres diff in y
# 22.253805503488284 metres diff in z
